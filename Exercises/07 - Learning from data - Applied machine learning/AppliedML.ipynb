# %% [markdown]
# ## All you need is love… And a pet!
#
# <img src="img/dataset-cover.jpg" width="920">
#
# Here we are going to build a classifier to predict whether an animal from an animal shelter will be adopted or not (aac_intakes_outcomes.csv, available at: https://www.kaggle.com/aaronschlegel/austin-animal-center-shelter-intakes-and-outcomes/version/1#aac_intakes_outcomes.csv). You will be working with the following features:
#
# 1. *animal_type:* Type of animal. May be one of 'cat', 'dog', 'bird', etc.
# 2. *intake_year:* Year of intake
# 3. *intake_condition:* The intake condition of the animal. Can be one of 'normal', 'injured', 'sick', etc.
# 4. *intake_number:* The intake number denoting the number of occurrences the animal has been brought into the shelter. Values higher than 1 indicate the animal has been taken into the shelter on more than one occasion.
# 5. *intake_type:* The type of intake, for example, 'stray', 'owner surrender', etc.
# 6. *sex_upon_intake:* The gender of the animal and if it has been spayed or neutered at the time of intake
# 7. *age_upon\_intake_(years):* The age of the animal upon intake represented in years
# 8. *time_in_shelter_days:* Numeric value denoting the number of days the animal remained at the shelter from intake to outcome.
# 9. *sex_upon_outcome:* The gender of the animal and if it has been spayed or neutered at time of outcome
# 10. *age_upon\_outcome_(years):* The age of the animal upon outcome represented in years
# 11. *outcome_type:* The outcome type. Can be one of ‘adopted’, ‘transferred’, etc.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy as sp
from itertools import combinations 
import ast
from sklearn.linear_model import LogisticRegression
import seaborn as sn
# %matplotlib inline

data_folder = './data/'

# %% [markdown]
# ### A) Load the dataset and convert categorical features to a suitable numerical representation (use dummy-variable encoding).
# - Split the data into a training set (80%) and a test set (20%). Pair each feature vector with the corresponding label, i.e., whether the outcome_type is adoption or not.
# - Standardize the values of each feature in the data to have mean 0 and variance 1.
#
# The use of external libraries is not permitted in part A, except for numpy and pandas.
# You can drop entries with missing values.

# %%
columns = ['animal_type', 'intake_year', 'intake_condition', 'intake_number', 'intake_type', 'sex_upon_intake', \
          'age_upon_intake_(years)', 'time_in_shelter_days', 'sex_upon_outcome', 'age_upon_outcome_(years)', \
          'outcome_type']
original_data = pd.read_csv(data_folder+'aac_intakes_outcomes.csv', usecols=columns)

# %%
original_data.dropna(inplace=True)

# %%
outcome_type_to_drop = ['outcome_type_'+type_name for type_name in original_data.outcome_type.unique().tolist() if type_name != 'Adoption']
outcome_type_to_drop
# Out:
# ['outcome_type_Return to Owner',
#  'outcome_type_Transfer',
#  'outcome_type_Euthanasia',
#  'outcome_type_Died',
#  'outcome_type_Rto-Adopt',
#  'outcome_type_Missing',
#  'outcome_type_Disposal',
#  'outcome_type_Relocate']

# %%
original_data_dummies = pd.get_dummies(original_data)
original_data_dummies.drop(outcome_type_to_drop, axis=1, inplace=True)

# %%
df_test_ori = original_data_dummies.sample(frac=0.2, random_state=2).copy()
df_test_ori
# Out:
#        age_upon_outcome_(years)  age_upon_intake_(years)  intake_year  \
# 75840                  0.821918                 0.739726         2017
# 31405                  2.000000                 2.000000         2015
# 411                    7.000000                 7.000000         2014
# 72525                  2.000000                 2.000000         2017
# 78488                  1.000000                 1.000000         2018
# ...                         ...                      ...          ...
# 57359                  0.038356                 0.038356         2016
# 64196                  1.000000                 1.000000         2017
# 20874                  0.164384                 0.164384         2014
# 75157                  3.000000                 3.000000         2017
# 72476                  2.000000                 2.000000         2018
#
#        intake_number  time_in_shelter_days  outcome_type_Adoption  \
# 75840            1.0              2.929167                  False
# 31405            1.0              0.039583                  False
# 411              1.0              3.986111                  False
# 72525            1.0              0.970139                  False
# 78488            1.0              4.514583                  False
# ...              ...                   ...                    ...
# 57359            1.0              0.244444                  False
# 64196            1.0              0.819444                  False
# 20874            1.0              4.197917                   True
# 75157            1.0              8.079861                  False
# 72476            1.0              7.043750                   True
#
#        sex_upon_outcome_Intact Female  sex_upon_outcome_Intact Male  \
# 75840                           False                          True
# 31405                           False                         False
# 411                             False                         False
# 72525                           False                         False
# 78488                           False                         False
# ...                               ...                           ...
# 57359                           False                         False
# 64196                           False                         False
# 20874                           False                         False
# 75157                           False                         False
# 72476                           False                         False
#
#        sex_upon_outcome_Neutered Male  sex_upon_outcome_Spayed Female  ...  \
# 75840                           False                           False  ...
# 31405                           False                           False  ...
# 411                             False                            True  ...
# 72525                            True                           False  ...
# 78488                           False                            True  ...
# ...                               ...                             ...  ...
# 57359                           False                           False  ...
# 64196                           False                            True  ...
# 20874                            True                           False  ...
# 75157                           False                            True  ...
# 72476                            True                           False  ...
#
#        intake_type_Euthanasia Request  intake_type_Owner Surrender  \
# 75840                           False                        False
# 31405                           False                        False
# 411                             False                         True
# 72525                           False                         True
# 78488                           False                        False
# ...                               ...                          ...
# 57359                           False                        False
# 64196                           False                        False
# 20874                           False                        False
# 75157                           False                        False
# 72476                           False                         True
#
#        intake_type_Public Assist  intake_type_Stray  intake_type_Wildlife  \
# 75840                      False               True                 False
# 31405                      False              False                  True
# 411                        False              False                 False
# 72525                      False              False                 False
# 78488                      False               True                 False
# ...                          ...                ...                   ...
# 57359                      False               True                 False
# 64196                      False               True                 False
# 20874                      False               True                 False
# 75157                      False               True                 False
# 72476                      False              False                 False
#
#        sex_upon_intake_Intact Female  sex_upon_intake_Intact Male  \
# 75840                          False                         True
# 31405                          False                        False
# 411                            False                        False
# 72525                          False                        False
# 78488                           True                        False
# ...                              ...                          ...
# 57359                          False                        False
# 64196                           True                        False
# 20874                          False                         True
# 75157                           True                        False
# 72476                          False                        False
#
#        sex_upon_intake_Neutered Male  sex_upon_intake_Spayed Female  \
# 75840                          False                          False
# 31405                          False                          False
# 411                            False                           True
# 72525                           True                          False
# 78488                          False                          False
# ...                              ...                            ...
# 57359                          False                          False
# 64196                          False                          False
# 20874                          False                          False
# 75157                          False                          False
# 72476                           True                          False
#
#        sex_upon_intake_Unknown
# 75840                    False
# 31405                     True
# 411                      False
# 72525                    False
# 78488                    False
# ...                        ...
# 57359                     True
# 64196                    False
# 20874                    False
# 75157                    False
# 72476                    False
#
# [15932 rows x 33 columns]

# %%
df_train_ori = original_data_dummies.drop(df_test_ori.index).copy()
df_train_ori
# Out:
#        age_upon_outcome_(years)  age_upon_intake_(years)  intake_year  \
# 2                      6.000000                 6.000000         2014
# 3                     10.000000                10.000000         2014
# 5                     15.000000                15.000000         2013
# 6                     15.000000                15.000000         2014
# 7                     15.000000                15.000000         2014
# ...                         ...                      ...          ...
# 79666                  0.038356                 0.038356         2018
# 79668                  2.000000                 2.000000         2018
# 79669                  1.000000                 1.000000         2018
# 79670                  0.821918                 0.410959         2018
# 79671                 10.000000                10.000000         2018
#
#        intake_number  time_in_shelter_days  outcome_type_Adoption  \
# 2                3.0              1.113889                  False
# 3                1.0              4.970139                  False
# 5                1.0              0.870833                  False
# 6                1.0              0.178472                  False
# 7                1.0              0.213194                  False
# ...              ...                   ...                    ...
# 79666            1.0              0.708333                  False
# 79668            1.0              0.053472                  False
# 79669            1.0              0.047917                  False
# 79670            1.0              1.762500                  False
# 79671            1.0              0.813889                  False
#
#        sex_upon_outcome_Intact Female  sex_upon_outcome_Intact Male  \
# 2                               False                         False
# 3                               False                         False
# 5                               False                         False
# 6                                True                         False
# 7                               False                         False
# ...                               ...                           ...
# 79666                           False                         False
# 79668                           False                         False
# 79669                           False                         False
# 79670                           False                          True
# 79671                           False                         False
#
#        sex_upon_outcome_Neutered Male  sex_upon_outcome_Spayed Female  ...  \
# 2                                True                           False  ...
# 3                                True                           False  ...
# 5                               False                            True  ...
# 6                               False                           False  ...
# 7                                True                           False  ...
# ...                               ...                             ...  ...
# 79666                           False                           False  ...
# 79668                           False                           False  ...
# 79669                           False                           False  ...
# 79670                           False                           False  ...
# 79671                           False                            True  ...
#
#        intake_type_Euthanasia Request  intake_type_Owner Surrender  \
# 2                               False                        False
# 3                               False                         True
# 5                               False                        False
# 6                               False                        False
# 7                               False                        False
# ...                               ...                          ...
# 79666                           False                        False
# 79668                           False                        False
# 79669                           False                        False
# 79670                           False                        False
# 79671                           False                        False
#
#        intake_type_Public Assist  intake_type_Stray  intake_type_Wildlife  \
# 2                           True              False                 False
# 3                          False              False                 False
# 5                          False               True                 False
# 6                          False               True                 False
# 7                          False               True                 False
# ...                          ...                ...                   ...
# 79666                      False               True                 False
# 79668                      False              False                  True
# 79669                      False              False                  True
# 79670                      False               True                 False
# 79671                      False               True                 False
#
#        sex_upon_intake_Intact Female  sex_upon_intake_Intact Male  \
# 2                              False                        False
# 3                              False                        False
# 5                              False                        False
# 6                               True                        False
# 7                              False                        False
# ...                              ...                          ...
# 79666                          False                        False
# 79668                          False                        False
# 79669                          False                        False
# 79670                          False                         True
# 79671                          False                        False
#
#        sex_upon_intake_Neutered Male  sex_upon_intake_Spayed Female  \
# 2                               True                          False
# 3                               True                          False
# 5                              False                           True
# 6                              False                          False
# 7                               True                          False
# ...                              ...                            ...
# 79666                          False                          False
# 79668                          False                          False
# 79669                          False                          False
# 79670                          False                          False
# 79671                          False                           True
#
#        sex_upon_intake_Unknown
# 2                        False
# 3                        False
# 5                        False
# 6                        False
# 7                        False
# ...                        ...
# 79666                     True
# 79668                     True
# 79669                     True
# 79670                    False
# 79671                    False
#
# [63729 rows x 33 columns]

# %%
mean = df_train_ori.mean()
std = df_train_ori.std() # std not var!!!

numerical_cols = ['intake_year', 'intake_number', 'age_upon_intake_(years)', 'time_in_shelter_days', 'age_upon_outcome_(years)']

df_train = df_train_ori.copy()

for col_name in numerical_cols:
    df_train[col_name] = (df_train_ori[col_name] - mean[col_name]) / std[col_name]

df_test = df_test_ori.copy()

for col_name in numerical_cols:
    df_test[col_name] = (df_test_ori[col_name] - mean[col_name]) / std[col_name]

# %% [markdown]
# ### B) Train a logistic regression classifier on your training set. Logistic regression returns probabilities as predictions, so in order to arrive at a binary prediction, you need to put a threshold on the predicted probabilities.
# - For the decision threshold of 0.5, present the performance of your classifier on the test set by displaying the confusion matrix. Based on the confusion matrix, manually calculate accuracy, precision, recall, and F1-score with respect to the positive and the negative class.

# %%
model = LogisticRegression(max_iter=10000)

X = df_train.drop('outcome_type_Adoption', axis=1)
y = df_train['outcome_type_Adoption']

model.fit(X, y)
# Out:
# LogisticRegression(max_iter=10000)

# %%
X_test = df_test.drop('outcome_type_Adoption', axis=1)
y_test = df_test['outcome_type_Adoption']

y_predict = model.predict_proba(X_test)
y_predict
# Out:
# array([[9.23758995e-01, 7.62410049e-02],
#        [9.99561456e-01, 4.38543583e-04],
#        [6.57388556e-01, 3.42611444e-01],
#        ...,
#        [3.09947720e-01, 6.90052280e-01],
#        [2.63386341e-01, 7.36613659e-01],
#        [3.78697467e-01, 6.21302533e-01]])

# %%
def calc_confusion_matrix(label_predicted, label_gt, decision_threshold=0.5):

    label_predicted_binary = label_predicted[:, 1] > decision_threshold

    TP = np.sum(np.logical_and(label_predicted_binary==1, label_gt==1))
    FP = np.sum(np.logical_and(label_predicted_binary==1, label_gt==0))
    TN = np.sum(np.logical_and(label_predicted_binary==0, label_gt==0))
    FN = np.sum(np.logical_and(label_predicted_binary==0, label_gt==1))

    df_matrix = pd.DataFrame([[TP, FP], [FN, TN]], index=['Yes', 'No'], columns=['Positive', 'Negative'])

    return df_matrix


def calc_all_scores(confusion_matrix):

    m = confusion_matrix
    acc = (m.iloc[0, 0] + m.iloc[1, 1]) / m.sum().sum()
    p_recall = m.iloc[0, 0] / m['Positive'].sum()
    p_precision = m.iloc[0, 0] / m.loc['Yes'].sum()
    p_f1 = 2 * p_recall * p_precision / (p_precision + p_recall)
    n_recall = m.iloc[1, 1] / m['Negative'].sum()
    n_precision = m.iloc[1, 1] / m.loc['No'].sum()
    n_f1 = 2 * n_recall * n_precision / (n_precision + n_recall)

    return acc, p_recall, p_precision, p_f1, n_recall, n_precision, n_f1

# %%
m = calc_confusion_matrix(y_predict, y_test)
m
# Out:
#      Positive  Negative
# Yes      5503      1693
# No       1215      7521

# %%
acc, p_recall, p_precision, p_f1, n_recall, n_precision, n_f1 = calc_all_scores(m)

print('Accuracy: {0:1.3f}'.format((m.iloc[0, 0] + m.iloc[1, 1]) / m.sum().sum()))

print('\nPositive case:')
print('Recall: {0:1.3f}'.format(p_recall))
print('Precision: {0:1.3f}'.format(p_precision))
print('F-1 score: {0:1.3f}'.format(2*p_recall*p_precision/(p_recall+p_precision)))

print('\nNegative case:')

print('Recall: {0:1.3f}'.format(n_recall))
print('Precision: {0:1.3f}'.format(n_precision))
print('F-1 score: {0:1.3f}'.format(2*n_recall*n_precision/(n_recall+n_precision)))
# Out:
# Accuracy: 0.817
#
# Positive case:
# Recall: 0.819
# Precision: 0.765
# F-1 score: 0.791
#
# Negative case:
# Recall: 0.816
# Precision: 0.861
# F-1 score: 0.838

# %% [markdown]
# ### C) Vary the value of the threshold in the range from 0 to 1 and visualize the value of accuracy, precision, recall, and F1-score (with respect to both classes) as a function of the threshold.

# %%
thresholds = np.linspace(0,1,100)

acc_col = []
p_recall_col = []
p_precision_col = []
p_f1_col = []
n_recall_col = []
n_precision_col = []
n_f1_col = []

for threshold in thresholds:
    acc, p_recall, p_precision, p_f1, n_recall, n_precision, n_f1 = \
        calc_all_scores(calc_confusion_matrix(y_predict, y_test, decision_threshold=threshold))
    acc_col.append(acc)
    p_recall_col.append(p_recall)
    p_precision_col.append(p_precision)
    p_f1_col.append(p_f1)
    n_recall_col.append(n_recall)
    n_precision_col.append(n_precision)
    n_f1_col.append(n_f1)

df_threshold = pd.DataFrame({'threshold': thresholds,
                             'acc': acc_col,
                             'p_recall': p_recall_col,
                             'p_precision': p_precision_col,
                             'p_f1': p_f1_col,
                             'n_recall': n_recall_col,
                             'n_precision': n_precision_col,
                             'n_f1': n_f1_col})
df_threshold.set_index('threshold', inplace=True)
df_threshold
# Out:
# C:\Users\Theodore\AppData\Local\Temp\ipykernel_5104\1504733665.py:23: RuntimeWarning: invalid value encountered in scalar divide
#   n_precision = m.iloc[1, 1] / m.loc['No'].sum()
# C:\Users\Theodore\AppData\Local\Temp\ipykernel_5104\1504733665.py:20: RuntimeWarning: invalid value encountered in scalar divide
#   p_precision = m.iloc[0, 0] / m.loc['Yes'].sum()
#                 acc  p_recall  p_precision      p_f1  n_recall  n_precision  \
# threshold
# 0.000000   0.421667  1.000000     0.421667  0.593201  0.000000          NaN
# 0.010101   0.498117  0.999702     0.456560  0.626843  0.132407     0.998363
# 0.020202   0.525358  0.998363     0.470403  0.639493  0.180486     0.993429
# 0.030303   0.538476  0.996874     0.477368  0.645587  0.204254     0.988965
# 0.040404   0.556804  0.995534     0.487499  0.654499  0.236922     0.986444
# ...             ...       ...          ...       ...       ...          ...
# 0.959596   0.591828  0.037660     0.869416  0.072193  0.995876     0.586663
# 0.969697   0.588250  0.028431     0.852679  0.055027  0.996418     0.584479
# 0.979798   0.585551  0.020988     0.844311  0.040959  0.997178     0.582810
# 0.989899   0.582852  0.013397     0.833333  0.026370  0.998046     0.581143
# 1.000000   0.578333  0.000000          NaN       NaN  1.000000     0.578333
#
#                n_f1
# threshold
# 0.000000        NaN
# 0.010101   0.233806
# 0.020202   0.305474
# 0.030303   0.338581
# 0.040404   0.382078
# ...             ...
# 0.959596   0.738363
# 0.969697   0.736779
# 0.979798   0.735658
# 0.989899   0.734563
# 1.000000   0.732840
#
# [100 rows x 7 columns]

# %%
fig, axes = plt.subplots(3, 3, sharex=True, sharey=True, figsize=(10,8))

plot_name = ['p_recall', 'p_precision', 'p_f1', 'n_recall', 'n_precision', 'n_f1', 'acc']

for ax, name in zip(axes.flat, plot_name):
    df_threshold[name].plot(ax=ax)
    ax.set_title(name)

# %% [markdown]
# ### D) Plot in a bar chart the coefficients of the logistic regression sorted by their contribution to the prediction.

# %%
df_coef = pd.DataFrame({'feature': X.columns,
                        'coef': model.coef_[0]})
df_coef.sort_values(by='coef', ascending=False, inplace=True)
df_coef
# Out:
#                            feature      coef
# 10                animal_type_Bird  2.407043
# 8   sex_upon_outcome_Spayed Female  2.138616
# 7   sex_upon_outcome_Neutered Male  2.093430
# 23     intake_type_Owner Surrender  1.800115
# 0         age_upon_outcome_(years)  1.273537
# 27   sex_upon_intake_Intact Female  1.089297
# 28     sex_upon_intake_Intact Male  1.008296
# 25               intake_type_Stray  0.952923
# 4             time_in_shelter_days  0.801375
# 14           intake_condition_Aged  0.606081
# 17         intake_condition_Normal  0.403480
# 20       intake_condition_Pregnant  0.358313
# 2                      intake_year  0.201262
# 18        intake_condition_Nursing  0.104793
# 19          intake_condition_Other  0.066991
# 3                    intake_number  0.058548
# 22  intake_type_Euthanasia Request -0.017117
# 21           intake_condition_Sick -0.083720
# 16        intake_condition_Injured -0.094020
# 13               animal_type_Other -0.346566
# 30   sex_upon_intake_Spayed Female -0.359648
# 29   sex_upon_intake_Neutered Male -0.514106
# 24       intake_type_Public Assist -0.779237
# 11                 animal_type_Cat -1.015055
# 12                 animal_type_Dog -1.072747
# 9         sex_upon_outcome_Unknown -1.251165
# 31         sex_upon_intake_Unknown -1.251165
# 15          intake_condition_Feral -1.389242
# 5   sex_upon_outcome_Intact Female -1.408966
# 6     sex_upon_outcome_Intact Male -1.599239
# 1          age_upon_intake_(years) -1.656658
# 26            intake_type_Wildlife -1.984009

# %%
plt.subplots(figsize=(10,7))
plt.barh(df_coef.feature, df_coef.coef)
# Out:
# <BarContainer object of 32 artists>

# %% [markdown]
# ## Question 1: Which of the following metrics is most suitable when you are dealing with unbalanced classes?
#
# - a) F1 Score
# - b) Recall
# - c) Precision
# - d) Accuracy

# %%
# a

# %% [markdown]
# ## Question 2: You are working on a binary classification problem. You trained a model on a training dataset and got the following confusion matrix on the test dataset. What is true about the evaluation metrics (rounded to the second decimal point):
#
# |            | Pred = NO|Pred=YES|
# |------------|----------|--------|
# | Actual NO  |    50    |   10   |
# | Actual YES |    5     |   100  |
#
# - a) Accuracy is 0.95
# - b) Accuracy is 0.85
# - c) False positive rate is 0.95
# - d) True positive rate is 0.95

# %%
# d
